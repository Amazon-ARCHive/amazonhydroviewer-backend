# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
# hydroview_grid_subsample.py
import numpy as np
import xarray as xr
# from scipy import ndimage
# import warnings

class HydroViewerSubsampler:
    """
    Poseidon-style grid subsampling for HydroViewer xarray data
    Adapted from Poseidon's grid_subsample.py
    """
    
    def __init__(self, data, resolution=256):
        """
        Parameters
        ----------
        data : xr.DataArray
            Your data with dims (time, category, lat, lon)
        resolution : int
            Tile resolution (pixels per tile)
        """
        self.full_data = data
        self.resolution = resolution
        self.lat = data.lat.values
        self.lon = data.lon.values
        self.nlat = len(self.lat)
        self.nlon = len(self.lon)
        
        # Calculate grid spacing
        self.dlat = np.abs(np.diff(self.lat).mean())
        self.dlon = np.abs(np.diff(self.lon).mean())
        
        print(f"Full grid: {self.nlat}×{self.nlon} = {self.nlat*self.nlon:,} cells")
        print(f"Grid spacing: Δlat={self.dlat:.4f}°, Δlon={self.dlon:.4f}°")
    
    def find_common_factors(self, num1, num2):
        """Find all common factors of two numbers (from Poseidon)"""
        common = []
        g = np.gcd(num1, num2)
        for i in range(1, int(np.sqrt(g)) + 1):
            if g % i == 0:
                common.append(i)
                if g != i * i:
                    common.append(g // i)
        return np.array(sorted(common))
    
    def pick_grain_sizes(self, zooms, factor=1.0):
        """
        Calculate appropriate grain size for each zoom level
        Adapted from Poseidon's pick_grain_size
        
        Parameters
        ----------
        zooms : list or np.ndarray
            Zoom levels (e.g., [0, 1, 2, 3, 4, 5])
        factor : float
            Adjustment factor for grain selection
        
        Returns
        -------
        grains : list
            Grain size for each zoom level
        """
        # Representative grid spacing in meters (approximate)
        rep_dx = 111000 * self.dlon  # degrees to meters at equator
        
        # Calculate required resolution at each zoom level
        # Web Mercator: world width = 2^zoom * tile_resolution pixels
        interp_dx = 6371e3 * 2 * np.pi / (2**np.array(zooms)) / self.resolution
        
        # Find available grain sizes (factors of grid dimensions)
        avail = self.find_common_factors(self.nlat, self.nlon)
        avail_dx = avail * rep_dx
        
        print(f"\nAvailable grain sizes: {avail}")
        print(f"Available resolutions (m): {avail_dx}")
        
        grains = []
        for zoom, dx in zip(zooms, interp_dx):
            # Find grain that gives resolution closest to target
            idx = np.searchsorted(avail_dx, dx * factor)
            idx = min(idx, len(avail) - 1)
            grain = avail[idx]
            grains.append(grain)
            
            actual_res = avail_dx[idx]
            print(f"Zoom {zoom}: target={dx:.0f}m, actual={actual_res:.0f}m, grain={grain}")
        
        return grains
    
    def subsample_data(self, grain, method='auto', variable=None):
        """
        Subsample data by taking every grain-th point
        Adapted from Poseidon's subsample_ocedata
        
        Parameters
        ----------
        grain : int
            Subsampling factor
        
        Returns
        -------
        subsampled : xr.DataArray
            Coarse-grained data
        """
        if grain == 1:
            return self.full_data
        
        # Calculate starting indices (centered sampling)
        lat_start = int(np.ceil(grain / 2) - 1)
        lon_start = int(np.ceil(grain / 2) - 1)

        shifted=self.full_data.isel(
            lat=slice(lat_start, None),
            lon=slice(lon_start, None)
        )

        coarsened=shifted.coarsen(
            lat=grain,
            lon=grain,
            boundary='trim'
        )
        
        # Subsample using slice
        # subsampled = 

        if method=="auto":
            if variable == 'Streamflow_tavg':
                method='max'
            else:
                method='mean'
        
        if method == "max":
            subsampled = coarsened.max(skipna=True)
        elif method == "mean":
            subsampled = coarsened.mean(skipna=True)
        elif method == "nearest":
            subsampled = self.full_data.isel(
                lat=slice(lat_start, self.nlat, grain),
                lon=slice(lon_start, self.nlon, grain)
            )
        else:
            raise ValueError(f"Unknown subsample method: {method}")
                
        print(f"  Grain {grain}: {len(subsampled.lat)}×{len(subsampled.lon)} = "
              f"{len(subsampled.lat)*len(subsampled.lon):,} cells "
              f"({100*(1-len(subsampled.lat)*len(subsampled.lon)/(self.nlat*self.nlon)):.1f}% reduction)")
        
        return subsampled
    
    def generate_pyramid(self, zooms=None, variable = None):
        """
        Generate the full resolution pyramid
        
        Parameters
        ----------
        zooms : list, optional
            Zoom levels to generate. Default: [0, 1, 2, 3, 4, 5]
        
        Returns
        -------
        pyramid : dict
            Dictionary mapping zoom level to data
        grain_map : dict
            Dictionary mapping zoom level to grain size
        """
        if zooms is None:
            zooms = list(range(6))  # 6 levels like your sketch
        
        print("\n" + "="*60)
        print("GENERATING RESOLUTION PYRAMID")
        print("="*60)
        
        # Calculate grain sizes
        grains = self.pick_grain_sizes(zooms)
        
        # Get unique grains
        unique_grains = sorted(set(grains))
        
        print(f"\nUnique grain sizes needed: {unique_grains}")
        print("\nSubsampling data...")
        
        # Create subsampled datasets
        grain_to_data = {}
        for grain in unique_grains:
            grain_to_data[grain] = self.subsample_data(grain, method='auto', variable=variable)
        
        # Map zoom levels to data
        pyramid = {}
        grain_map = {}
        for zoom, grain in zip(zooms, grains):
            pyramid[zoom] = grain_to_data[grain]
            grain_map[zoom] = grain
        
        print("\n" + "="*60)
        print("PYRAMID SUMMARY")
        print("="*60)
        for zoom in zooms:
            data = pyramid[zoom]
            grain = grain_map[zoom]
            print(f"Zoom {zoom}: {len(data.lat):4d}×{len(data.lon):4d} cells, grain={grain:2d}")
        
        return pyramid, grain_map


def lonlat_for_tile(zoom, tile_x, tile_y, resolution=256):
    """
    Create lat/lon coordinates for a Web Mercator tile
    Adapted from Poseidon's lonlat4global_map
    
    Parameters
    ----------
    zoom : int
        Zoom level
    tile_x : int
        Tile X coordinate
    tile_y : int
        Tile Y coordinate
    resolution : int
        Pixels per tile
    
    Returns
    -------
    lon, lat : np.ndarray
        2D arrays of coordinates
    """
    n_tiles = 2 ** zoom
    data_bounds = {'lon_min': -81.975, 'lon_max': -49.025, 'lat_min': -20.975, 'lat_max': 5.975}
    # Total extent
    lon_min, lon_max = data_bounds['lon_min'], data_bounds['lon_max']
    lat_min, lat_max = data_bounds['lat_min'], data_bounds['lat_max']

    # Size of each tile in degrees
    tile_width_lon = (lon_max - lon_min) / n_tiles
    tile_height_lat = (lat_max - lat_min) / n_tiles

    # Tile bounds
    tile_lon_min = lon_min + tile_x * tile_width_lon
    tile_lon_max = lon_min + (tile_x + 1) * tile_width_lon
    tile_lat_min = lat_min + tile_y * tile_height_lat
    tile_lat_max = lat_min + (tile_y + 1) * tile_height_lat

    # Create pixel coordinates within this tile
    lon_1d = np.linspace(tile_lon_min, tile_lon_max, resolution)
    lat_1d = np.linspace(tile_lat_min, tile_lat_max, resolution)
    
    lon, lat = np.meshgrid(lon_1d, lat_1d)
    
    return lon, lat
    

def get_tile_data(pyramid, zoom, tile_x, tile_y, time_idx=0, category_idx=0):
    """
    Extract data for a specific tile at a given zoom level
    
    Parameters
    ----------
    pyramid : dict
        Resolution pyramid from generate_pyramid
    zoom : int
        Zoom level
    tile_x, tile_y : int
        Tile coordinates
    time_idx : int
        Time index
    category_idx : int
        Category index
    
    Returns
    -------
    tile_data : np.ndarray
        256×256 array of data values
    lon, lat : np.ndarray
        Coordinate grids
    """
    # Get coordinates for this tile
    lon, lat = lonlat_for_tile(zoom, tile_x, tile_y)
    print(f"Tile bounds: lon=[{lon.min():.2f}, {lon.max():.2f}], "
        f"lat=[{lat.min():.2f}, {lat.max():.2f}]")
    
    # Get appropriate resolution data
    data = pyramid[zoom]
    # Select time and category
    data_slice = data.isel(time=time_idx, category=category_idx)

    # Get valid (non-NaN) points only
    # valid_mask = ~np.isnan(data)
    
    # if valid_mask.sum() == 0:
    #     print("WARNING: All data is NaN!")
    #     return np.full(lon.shape, np.nan), lon, lat
    
    # valid_points = np.column_stack([
    #     data_slice[valid_mask],
    #     data_slice[valid_mask]
    # ])
    # valid_values = data_slice[valid_mask]

    # from scipy.interpolate import NearestNDInterpolator

    # #Create interpolator using only valid points
    # interp = NearestNDInterpolator(valid_points, valid_values)

    # # Interpolate
    # lat_flat = lat.ravel()
    # lon_flat = lon.ravel()
    # points = np.column_stack([lat_flat, lon_flat])
    
    # tile_data_flat = interp(points)
    # tile_data = tile_data_flat.reshape(lon.shape)

    # Interpolate to tile coordinates
    # This is where you'd implement more sophisticated interpolation
    # For now, using simple nearest neighbor
    tile_data_flat = data_slice.interp(
        lat=xr.DataArray(lat.ravel(), dims='points'),
        lon=xr.DataArray(lon.ravel(), dims='points'),
        method='nearest'
    ).values
    print(f'\n Type {type(tile_data_flat)}')
    tile_data = tile_data_flat.reshape(lon.shape)
    
    return tile_data, lon, lat

# %%
ds = xr.open_zarr('../get_ldas_probabilistic_output/tmp/2026_may_tercile_prob_max_Streamflow_tavg')
da = ds['Streamflow_tavg']
da
# Out:
# <xarray.DataArray 'Streamflow_tavg' (category: 3, time: 6, lat: 540, lon: 660)> Size: 51MB
# dask.array<open_dataset-Streamflow_tavg, shape=(3, 6, 540, 660), dtype=float64, chunksize=(1, 6, 540, 660), chunktype=numpy.ndarray>
# Coordinates:
#   * category  (category) int64 24B 0 1 2
#   * time      (time) datetime64[ns] 48B 2026-05-31 2026-06-30 ... 2026-10-31
#   * lat       (lat) float64 4kB -20.98 -20.93 -20.88 ... 5.875 5.925 5.975
#   * lon       (lon) float64 5kB -81.97 -81.92 -81.88 ... -49.13 -49.08 -49.03

# %%
da = ds.isel(time = 5, category = 2)
da.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 da = ds.isel(time = 5, category = 2)
# ----> 2 da.plot()
#
# File ~/miniconda3/envs/analytics/lib/python3.12/site-packages/xarray/plot/accessor.py:921, in DatasetPlotAccessor.__call__(self, *args, **kwargs)
#     920 def __call__(self, *args, **kwargs) -> NoReturn:
# --> 921     raise ValueError(
#     922         "Dataset.plot cannot be called directly. Use "
#     923         "an explicit plot method, e.g. ds.plot.scatter(...)"
#     924     )
#
# ValueError: Dataset.plot cannot be called directly. Use an explicit plot method, e.g. ds.plot.scatter(...)

# %%
ds = ds.compute()

# Create subsampler
subsampler = HydroViewerSubsampler(ds, resolution=256)

# Generate 6-level pyramid (like your sketch)
pyramid, grain_map = subsampler.generate_pyramid(zooms=[4, 5, 6, 7, 8, 9], variable='Streamflow_tavg')

# Example: Get tile for zoom=3, tile coordinates (2, 1)
tile_data, lon, lat = get_tile_data(
    pyramid, 
    zoom=5, 
    tile_x=2, 
    tile_y=1,
    time_idx=0,
    category_idx=0
)

# Visualize
# plt.figure(figsize=(10, 8))
# plt.pcolormesh(lon, lat, tile_data, cmap='viridis')
# plt.colorbar(label='Value')
# plt.title('Tile at Zoom=3, X=2, Y=1')
# plt.xlabel('Longitude')
# plt.ylabel('Latitude')
# plt.show()
# Out:
# Full grid: 540×660 = 356,400 cells
# Grid spacing: Δlat=0.0500°, Δlon=0.0500°
#
# ============================================================
# GENERATING RESOLUTION PYRAMID
# ============================================================
#
# Available grain sizes: [ 1  2  3  4  5  6 10 12 15 20 30 60]
# Available resolutions (m): [  5550.          11100.          16650.          22200.
#   27750.          33300.          55500.          66600.
#   83250.         110999.99999999 166499.99999999 332999.99999998]
# Zoom 4: target=9773m, actual=11100m, grain=2
# Zoom 5: target=4886m, actual=5550m, grain=1
# Zoom 6: target=2443m, actual=5550m, grain=1
# Zoom 7: target=1222m, actual=5550m, grain=1
# Zoom 8: target=611m, actual=5550m, grain=1
# Zoom 9: target=305m, actual=5550m, grain=1
#
# Unique grain sizes needed: [np.int64(1), np.int64(2)]
#
# Subsampling data...
#   Grain 2: 270×330 = 89,100 cells (75.0% reduction)
#
# ============================================================
# PYRAMID SUMMARY
# ============================================================
# Zoom 4:  270× 330 cells, grain= 2
# Zoom 5:  540× 660 cells, grain= 1
# Zoom 6:  540× 660 cells, grain= 1
# Zoom 7:  540× 660 cells, grain= 1
# Zoom 8:  540× 660 cells, grain= 1
# Zoom 9:  540× 660 cells, grain= 1
# Tile bounds: lon=[-79.92, -78.89], lat=[-20.13, -19.29]
#
#  Type <class 'numpy.ndarray'>

# %%
# Visualize
plt.figure(figsize=(10, 8))
plt.pcolormesh(lon, lat, tile_data, cmap='Reds')
plt.colorbar(label='Value')
plt.title('Tile at Zoom=3, X=2, Y=1')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
def visualize_all_tiles(pyramid, zoom, data_bounds = {'lon_min': -81.975, 'lon_max': -49.025, 'lat_min': -20.975, 'lat_max': 5.975}
, time_idx=0, category_idx=2):
    """Show all tiles at a given zoom level"""
    n_tiles = 2 ** zoom
    
    plt.figure(figsize=(10, 8))
    
    # if n_tiles == 1:
    #     axes = np.array([[axes]])
    # elif n_tiles == 2:
    #     axes = axes.reshape(2, 2)
    
    for tile_y in range(n_tiles):
        for tile_x in range(n_tiles):
            #ax = axes[tile_y, tile_x]
            
            tile_data, lon, lat = get_tile_data(
                pyramid, zoom, tile_x, tile_y,
                time_idx, category_idx
            )
            
            plt.pcolormesh(lon, lat, tile_data, cmap='Reds', shading='auto')
            # ax.set_title(f'Tile ({tile_x}, {tile_y})')
            # ax.set_xlabel('Longitude')
            # ax.set_ylabel('Latitude')
            # plt.colorbar(im, ax=ax)
    
    plt.suptitle(f'All Tiles at Zoom {zoom}', fontsize=16)
    plt.colorbar(label='Value')
    plt.tight_layout()
    plt.show()

# Use it
visualize_all_tiles(pyramid, zoom=6)
# Out:
# Tile bounds: lon=[-81.97, -81.46], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[-20.98, -20.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[-20.55, -20.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[-20.13, -19.71]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[-19.71, -19.29]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[-19.29, -18.87]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[-18.87, -18.45]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[-18.45, -18.03]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[-18.03, -17.61]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[-17.61, -17.19]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[-17.61, -17.19]
#
# ...
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[4.71, 5.13]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[5.13, 5.55]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.97, -81.46], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-81.46, -80.95], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.95, -80.43], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-80.43, -79.92], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.92, -79.40], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-79.40, -78.89], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.89, -78.37], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-78.37, -77.86], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.86, -77.34], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-77.34, -76.83], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.83, -76.31], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-76.31, -75.80], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.80, -75.28], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-75.28, -74.77], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.77, -74.25], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-74.25, -73.74], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.74, -73.22], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-73.22, -72.71], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.71, -72.19], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-72.19, -71.68], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.68, -71.16], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-71.16, -70.65], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.65, -70.13], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-70.13, -69.62], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.62, -69.10], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-69.10, -68.59], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.59, -68.07], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-68.07, -67.56], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.56, -67.04], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-67.04, -66.53], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.53, -66.01], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-66.01, -65.50], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-65.50, -64.99], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.99, -64.47], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-64.47, -63.96], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.96, -63.44], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-63.44, -62.93], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.93, -62.41], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-62.41, -61.90], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.90, -61.38], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-61.38, -60.87], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.87, -60.35], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-60.35, -59.84], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.84, -59.32], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-59.32, -58.81], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.81, -58.29], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-58.29, -57.78], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.78, -57.26], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-57.26, -56.75], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.75, -56.23], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-56.23, -55.72], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.72, -55.20], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-55.20, -54.69], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.69, -54.17], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-54.17, -53.66], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.66, -53.14], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-53.14, -52.63], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.63, -52.11], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-52.11, -51.60], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.60, -51.08], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-51.08, -50.57], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.57, -50.05], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-50.05, -49.54], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>
# Tile bounds: lon=[-49.54, -49.02], lat=[5.55, 5.98]
#
#  Type <class 'numpy.ndarray'>

# %% [markdown]
# ## Check May 2026 Forecast Data

# %%
# Variable definitions
list_of_variables = {
    # 'Rainf_tavg': 'Average precipitation', 
    # 'Qair_f_tavg': 'Specific humidity',
    # 'Qs_tavg': 'Surface runoff',
    # 'Evap_tavg': 'Evapotranspiration',
    # 'Tair_f_tavg': 'Avg. air temperature',
    # 'SoilMoist_inst': 'Soil moisture',
    # 'SoilTemp_inst': 'Soil temperature',
    'Streamflow_tavg': 'Stream flow'
}

# Data directory
surface_model_file_path = r"/mnt/vast/prakrut/backup/lis_runs/malaria_amazon/forecast/monthly" # Input location on group server
#surface_model_file_path = rf"C:\Users\Kris\Documents\amazonforecast\data\hindcast\amazon_forecast" # Input local on local machine [for test purposes]

surface_model_file_path += '/ldas_fcst_2026_may01.nc'

# %%
ds = xr.open_dataset(surface_model_file_path)
#ds = xr.open_zarr('../get_ldas_probabilistic_output/tmp/2026_may_tercile_prob_max_Streamflow_tavg')
da = ds['Qair_f_tavg']
fig, ax = plt.subplots(6,7,figsize=(112, 60))
#fig, ax = plt.subplots(6,3,figsize=(48, 40))

# for t in range(0, 6):
#     for e in range(0, 3):
#         #print(e)
#         #da = ds['Qair_f_tavg']
#         ds['Streamflow_tavg'].isel(time = t, category = e).plot(ax=ax[t, e], cmap='Blues')
#         #plt.plot(x, y)

for t in range(0, 6):
    for e in range(0, 7):
        #print(e)
        #da = ds['Qair_f_tavg']
        da.isel(time = t, ensemble = e).plot(ax=ax[t, e], cmap='Blues')
        #plt.plot(x, y)
